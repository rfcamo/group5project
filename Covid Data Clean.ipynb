# %%
import pandas as pd
#retrieving data

# %%
cases_data = "Resources/time_series_covid19_confirmed_global_metricdate.csv"
cases_data = pd.read_csv(cases_data)
deaths_data = "Resources/time_series_covid19_deaths_global_metricdate.csv"
deaths_data = pd.read_csv(deaths_data)
recovered_data = "Resources/time_series_covid19_confirmed_global_metricdate.csv"
recovered_data = pd.read_csv(recovered_data)
precovid_data = "Resources/time_series_precovid19_australia.csv"
precovid_data = pd.read_csv(precovid_data)
cases_data.head()
# Out:
#   Province/State Country/Region       Lat       Long  22-01-20  23-01-20  \
# 0            NaN    Afghanistan  33.93911  67.709953         0         0
# 1            NaN        Albania  41.15330  20.168300         0         0
# 2            NaN        Algeria  28.03390   1.659600         0         0
# 3            NaN        Andorra  42.50630   1.521800         0         0
# 4            NaN         Angola -11.20270  17.873900         0         0
#
#    24-01-20  25-01-20  26-01-20  27-01-20  ...  12-04-21  13-04-21  14-04-21  \
# 0         0         0         0         0  ...     57242     57364     57492
# 1         0         0         0         0  ...    128518    128752    128959
# 2         0         0         0         0  ...    118645    118799    118975
# 3         0         0         0         0  ...     12581     12614     12641
# 4         0         0         0         0  ...     23549     23697     23841
#
#    15-04-21  16-04-21  17-04-21  18-04-21  19-04-21  20-04-21  21-04-21
# 0     57534     57612     57721     57793     57898     58037     58214
# 1    129128    129307    129456    129594    129694    129842    129980
# 2    119142    119323    119486    119642    119805    119992    120174
# 3     12641     12712     12771     12805     12805     12874     12917
# 4     23951     24122     24300     24389     24518     24661     24883
#
# [5 rows x 460 columns]

# %%
cases_data = cases_data.drop(["Lat", "Long"], axis = 1)
deaths_data = deaths_data.drop(["Lat", "Long"], axis = 1)
recovered_data = recovered_data.drop(["Lat", "Long"], axis = 1)
cases_data.head()
# Out:
#   Province/State Country/Region  22-01-20  23-01-20  24-01-20  25-01-20  \
# 0            NaN    Afghanistan         0         0         0         0
# 1            NaN        Albania         0         0         0         0
# 2            NaN        Algeria         0         0         0         0
# 3            NaN        Andorra         0         0         0         0
# 4            NaN         Angola         0         0         0         0
#
#    26-01-20  27-01-20  28-01-20  29-01-20  ...  12-04-21  13-04-21  14-04-21  \
# 0         0         0         0         0  ...     57242     57364     57492
# 1         0         0         0         0  ...    128518    128752    128959
# 2         0         0         0         0  ...    118645    118799    118975
# 3         0         0         0         0  ...     12581     12614     12641
# 4         0         0         0         0  ...     23549     23697     23841
#
#    15-04-21  16-04-21  17-04-21  18-04-21  19-04-21  20-04-21  21-04-21
# 0     57534     57612     57721     57793     57898     58037     58214
# 1    129128    129307    129456    129594    129694    129842    129980
# 2    119142    119323    119486    119642    119805    119992    120174
# 3     12641     12712     12771     12805     12805     12874     12917
# 4     23951     24122     24300     24389     24518     24661     24883
#
# [5 rows x 458 columns]

# %%
australian_cases = cases_data.loc[cases_data["Country/Region"] == 'Australia', :]
australian_deaths = deaths_data.loc[deaths_data["Country/Region"] == 'Australia', :]
australian_recovered = recovered_data.loc[recovered_data["Country/Region"] == 'Australia', :]
australian_cases
# Out:
#                   Province/State Country/Region  22-01-20  23-01-20  24-01-20  \
# 8   Australian Capital Territory      Australia         0         0         0
# 9                New South Wales      Australia         0         0         0
# 10            Northern Territory      Australia         0         0         0
# 11                    Queensland      Australia         0         0         0
# 12               South Australia      Australia         0         0         0
# 13                      Tasmania      Australia         0         0         0
# 14                      Victoria      Australia         0         0         0
# 15             Western Australia      Australia         0         0         0
#
#     25-01-20  26-01-20  27-01-20  28-01-20  29-01-20  ...  12-04-21  13-04-21  \
# 8          0         0         0         0         0  ...       123       123
# 9          0         3         4         4         4  ...      5344      5347
# 10         0         0         0         0         0  ...       112       112
# 11         0         0         0         0         1  ...      1506      1508
# 12         0         0         0         0         0  ...       666       675
# 13         0         0         0         0         0  ...       234       234
# 14         0         1         1         1         1  ...     20487     20487
# 15         0         0         0         0         0  ...       957       964
#
#     14-04-21  15-04-21  16-04-21  17-04-21  18-04-21  19-04-21  20-04-21  \
# 8        123       123       123       123       123       123       123
# 9       5356      5363      5370      5376      5384      5387      5395
# 10       113       113       113       119       119       129       132
# 11      1509      1515      1516      1518      1518      1518      1519
# 12       677       678       682       682       682       688       691
# 13       234       234       234       234       234       234       234
# 14     20492     20492     20494     20494     20498     20499     20502
# 15       965       966       967       973       975       978       980
#
#     21-04-21
# 8        123
# 9       5402
# 10       136
# 11      1520
# 12       693
# 13       234
# 14     20504
# 15       982
#
# [8 rows x 458 columns]

# %%
australian_cases_melt = australian_cases.melt(id_vars=["Province/State", "Country/Region"],
                     var_name ="Date", value_name="Covid_Cases") 
australian_deaths_melt = australian_deaths.melt(id_vars=["Province/State", "Country/Region"],
                     var_name ="Date", value_name="Covid_Cases") 
australian_recovered_melt = australian_recovered.melt(id_vars=["Province/State", "Country/Region"],
                     var_name ="Date", value_name="Covid_Cases") 
australian_cases_melt.head()
# Out:
#                  Province/State Country/Region      Date  Covid_Cases
# 0  Australian Capital Territory      Australia  22-01-20            0
# 1               New South Wales      Australia  22-01-20            0
# 2            Northern Territory      Australia  22-01-20            0
# 3                    Queensland      Australia  22-01-20            0
# 4               South Australia      Australia  22-01-20            0

# %%
australian_cases_melt["Date"] = pd.to_datetime(australian_cases_melt["Date"])
australian_deaths_melt["Date"] = pd.to_datetime(australian_deaths_melt["Date"])
australian_recovered_melt["Date"] = pd.to_datetime(australian_recovered_melt["Date"])

# %%
australian_cases_melt.head(10)
# Out:
#                  Province/State Country/Region       Date  Covid_Cases
# 0  Australian Capital Territory      Australia 2020-01-22            0
# 1               New South Wales      Australia 2020-01-22            0
# 2            Northern Territory      Australia 2020-01-22            0
# 3                    Queensland      Australia 2020-01-22            0
# 4               South Australia      Australia 2020-01-22            0
# 5                      Tasmania      Australia 2020-01-22            0
# 6                      Victoria      Australia 2020-01-22            0
# 7             Western Australia      Australia 2020-01-22            0
# 8  Australian Capital Territory      Australia 2020-01-23            0
# 9               New South Wales      Australia 2020-01-23            0

# %%
australian_cases_melt["Month"] = australian_cases_melt["Date"].dt.month
australian_deaths_melt["Month"] = australian_deaths_melt["Date"].dt.month
australian_recovered_melt["Month"] = australian_recovered_melt["Date"].dt.month
australian_cases_melt.head()
# Out:
#                  Province/State Country/Region       Date  Covid_Cases  Month
# 0  Australian Capital Territory      Australia 2020-01-22            0      1
# 1               New South Wales      Australia 2020-01-22            0      1
# 2            Northern Territory      Australia 2020-01-22            0      1
# 3                    Queensland      Australia 2020-01-22            0      1
# 4               South Australia      Australia 2020-01-22            0      1

# %%
australian_cases_melt["Year"] = australian_cases_melt["Date"].dt.year
australian_deaths_melt["Year"] = australian_deaths_melt["Date"].dt.year
australian_recovered_melt["Year"] = australian_recovered_melt["Date"].dt.year
australian_cases_melt.head()
# Out:
#                  Province/State Country/Region       Date  Covid_Cases  Month  \
# 0  Australian Capital Territory      Australia 2020-01-22            0      1
# 1               New South Wales      Australia 2020-01-22            0      1
# 2            Northern Territory      Australia 2020-01-22            0      1
# 3                    Queensland      Australia 2020-01-22            0      1
# 4               South Australia      Australia 2020-01-22            0      1
#
#    Year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 4  2020

# %%
cases_groupby = australian_cases_melt.groupby(["Province/State","Country/Region","Year", "Month"]).sum()
deaths_groupby = australian_deaths_melt.groupby(["Province/State","Country/Region","Year", "Month"]).sum()
recovered_groupby = australian_recovered_melt.groupby(["Province/State","Country/Region","Year", "Month"]).sum()
cases_groupby
# Out:
#                                                         Covid_Cases
# Province/State               Country/Region Year Month
# Australian Capital Territory Australia      2020 1              975
#                                                  2              978
#                                                  3             1561
#                                                  4             2862
#                                                  5             3021
# ...                                                             ...
# Western Australia            Australia      2021 8             3652
#                                                  9             3656
#                                                  10            3662
#                                                  11            3664
#                                                  12            3669
#
# [192 rows x 1 columns]
